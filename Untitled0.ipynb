# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# just paste the locataction you allocated for the google drive file, that you have been created as shourcut link based on readme description

# %%
# %cd /content/gdrive/MyDrive/Models
# Out:
# /content/gdrive/MyDrive/Models

# %%
# !git config --global user.name "itsparsa"
# !git config --global user.email "this.email.will.use.as.database@gmail.com"
# !git config --global user.password "Google1375"
token = "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"
username = "itsparsa"
repo = "communication_sec_"
# !git remote add coin https://{token}@github.com/{username}/{repo}
# !git add .
# !git commit -a -m "delete unneccessary"
# !git push coin master
# !git remote rm origin
# !git remote add coin https://{token}@github.com/{username}/{repo}
# !git push coin master
# Out:
# fatal: remote coin already exists.
# [master 990b259] delete unneccessary
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (96%)
# fatal: could not read Password for 'https://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@github.com': No such device or address
# fatal: No such remote: origin
# fatal: remote coin already exists.
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git add .

# %%
# !git config --global user.name "itsparsa"
# !git config --global user.email "this.email.will.use.as.database@gmail.com"
# !git config --global user.password "Google1375"

# %%
# !git commit -a -m "delete unneccessary"
# Out:
# [master 2823d01] delete unneccessary
#  3 files changed, 16 insertions(+), 1 deletion(-)
#  delete mode 100644 Colab Notebooks/Untitled0.ipynb
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 git.txt

# %%
# !git remote -v
# Out:
# coin	https://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@github.com/itsparsa/communication_sec_ (fetch)
# coin	https://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@github.com/itsparsa/communication_sec_ (push)

# %%
# !git config --global user.password "Google1375"

# %%
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
proj_path = "/content/gdrive/MyDrive/projects"

# %%
import os 
import sys
os.chdir('/content/gdrive/MyDrive/proj')
sys.path.append('/content/gdrive/MyDrive/Models')
from attack.celeverhans_attack import *
from autoencoder import aphl 
from deepmimo import Deep_MIMO
from mist import MIST
from pe import PE
import numpy as np

# %% [markdown]
# ## aphl

# %%
a1 = aphl("/content/gdrive/MyDrive/projects/RML2016.10a/",num_train_limit = 50000)
print("training aghl")
a1.train_gpu(epochs =10,batch_size=1024 )

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.5,
                     adv_train = False ,
                     batch = 128)

d = att.attack(a1,clean_limit=256)

# %% [markdown]
# ## attack

# %%
import subprocess
subprocess.call(['pip', 'install', "cleverhans"])
import math
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from easydict import EasyDict
from tensorflow.keras import Model
from tensorflow.keras.layers import AveragePooling2D, Conv2D

from cleverhans.tf2.attacks.projected_gradient_descent import projected_gradient_descent
from cleverhans.tf2.attacks.fast_gradient_method import fast_gradient_method


class Attack_handler:
    def __init__(self,nb_epochs= 1,eps = 0.05, adv_train = False ,batch = 128 ):
       for i,(key,value) in enumerate(locals().items()):
          if i < 1 : continue
          setattr(self,key,value)

    
    def attack(self,a,clean_limit=100):
      FLAGS = {"nb_epochs": self.nb_epochs ,"eps": self.eps,"adv_train": self.adv_train}
      self.start_attack(a,FLAGS,self.batch,clean_limit)


    @staticmethod
    def start_attack(a , FLAGS = {"nb_epochs": 1,"eps": 0.05,"adv_train": False} ,batch = 128,clean_limit =100):
        lim = int(a.X_train.shape[0]/128)
        train = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in [a.X_train,a.y_train]]

        def get_clean_data(a,limit):
              pred = a.model.predict(a.X_train)
              diff = np.mean(np.abs(pred - a.y_train),axis=-1)
              for i in range (len(a.y_train.shape)-2):
                  diff = np.mean(diff,axis=-1)
              best_answer_index = np.argsort(diff)
              return [a.X_train[best_answer_index][:limit] , a.y_train[best_answer_index][:limit]]
        
        print("getting clean data from model")
        clean = get_clean_data(a,clean_limit)
        lim = int(clean[0].shape[0]/128)
        test = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in clean]
        data = EasyDict(train=train, test=test)
        print(data.train[0].shape)
        print(data.test[0].shape)
        # Load training and test data
        model = a.model
        loss_object =tf.keras.losses.MeanSquaredError()
        optimizer = tf.optimizers.Adam(learning_rate=0.001)

        # Metrics to track the different accuracies.
        train_loss = tf.metrics.Mean(name="train_loss")
        test_acc = tf.keras.metrics.CategoricalAccuracy()
        test_acc_fgsm = tf.keras.metrics.CategoricalAccuracy()
        test_acc_pgd = tf.keras.metrics.CategoricalAccuracy()

        @tf.function
        def train_step(x, y):
            with tf.GradientTape() as tape:
                predictions = a.model(x)
                loss = loss_object(y, predictions)
            gradients = tape.gradient(loss, a.model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, a.model.trainable_variables))
            train_loss(loss)

        print("Train model with adversarial training")
        # Train model with adversarial training
        for epoch in range(FLAGS["nb_epochs"]):
            # keras like display of progress
            progress_bar_train = tf.keras.utils.Progbar(50000)
            for i in range(data.train[0].shape[0]):
                if FLAGS['adv_train']:
                    # Replace clean example with adversarial example for adversarial training
                    x = projected_gradient_descent(a.model, data.train[0][i,:], FLAGS['eps'], 0.01, 40, np.inf)
                train_step(data.train[0][i,:], data.train[1][i,:])
                progress_bar_train.add(data.train[0][i,:].shape[0], values=[("loss", train_loss.result())])

        print("\nEvaluate on clean and adversarial data")

        
        # Evaluate on clean and adversarial data

        progress_bar_test = tf.keras.utils.Progbar(10000)
        for i in range(data.test[0].shape[0]):
            print(data.test[0][i,:].shape)
            y_pred = a.model(data.test[0][i,:])
            test_acc(data.test[1][i,:], y_pred)

            x_fgm = fast_gradient_method(a.model, data.test[0][i,:], FLAGS['eps'], np.inf)
            y_pred_fgm = model(x_fgm)
            test_acc_fgsm(data.test[1][i,:], y_pred_fgm)

            x_pgd = projected_gradient_descent(a.model, data.test[0][i,:], FLAGS['eps'], 0.01, 40, np.inf)
            y_pred_pgd = a.model(x_pgd)
            test_acc_pgd(data.test[1][i,:], y_pred_pgd)

            progress_bar_test.add(data.test[0][i,:].shape[0])
        
        print(a.name)    

        print(
            "test acc on clean examples (%): {:.3f}".format(test_acc.result() * 100)
        )
        print(
            "test acc on FGM adversarial examples (%): {:.3f}".format(
                test_acc_fgsm.result() * 100
            )
        )
        print(
            "test acc on PGD adversarial examples (%): {:.3f}".format(
                test_acc_pgd.result() * 100
            )
        )

        return dict(acc = test_acc.result()*100,
                    acc_FGM = test_acc_fgsm.result()*100,
                    acc_pdg = test_acc_pgd.result()*100)

# %% [markdown]
# ## PE

# %%
p1 = PE(proj_path+"/project_3/PE", train_snr = np.arange(20, -4, -2))
print("training aghl")
p1.train_gpu(epochs =100,batch_size=1024 )

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(p1,clean_limit=1000)

# %% [markdown]
# ## DEEPMIMO

# %%
mim1 = Deep_MIMO(proj_path+    '/DeepMIMO2',
                                active_BS = 10,
                                user_row_first = 2,
                                user_row_last = 10,
                                bandwidth = 0.05,
                                subcarriers = 64 ,
                                subcarriers_sampling = 1 ,
                                subcarriers_limit = 32,
                                num_paths = 1,
                                num_set_antenna_M = 8,
                                MLP_DroupOut = True)

print("training DEEPMIMO")
mim1.train_gpu(epochs =100,batch_size=1024 )

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(mim1,clean_limit=1000)
# Out:
# attack
# getting clean data from model
# (9, 128, 10, 32, 2)
# (7, 128, 10, 32, 2)
# Train model with adversarial training
#  1152/50000 [..............................] - ETA: 33s - loss: 0.0525
# Evaluate on clean and adversarial data
# (128, 10, 32, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-04f0ca7f82a9> in <module>()
#       5                      batch = 128)
#       6
# ----> 7 d = att.attack(mim1,clean_limit=1000)
#
# <ipython-input-38-853d17091d42> in attack(self, a, clean_limit)
#      23     def attack(self,a,clean_limit=100):
#      24       FLAGS = {"nb_epochs": self.nb_epochs ,"eps": self.eps,"adv_train": self.adv_train}
# ---> 25       self.start_attack(a,FLAGS,self.batch,clean_limit)
#      26
#      27
#
# <ipython-input-38-853d17091d42> in start_attack(a, FLAGS, batch, clean_limit)
#      89             test_acc(data.test[1][i,:], y_pred)
#      90
# ---> 91             x_fgm = fast_gradient_method(a.model, data.test[0][i,:], FLAGS['eps'], np.inf)
#      92             y_pred_fgm = model(x_fgm)
#      93             test_acc_fgsm(data.test[1][i,:], y_pred_fgm)
#
# /usr/local/lib/python3.7/dist-packages/cleverhans/tf2/attacks/fast_gradient_method.py in fast_gradient_method(model_fn, x, eps, norm, loss_fn, clip_min, clip_max, y, targeted, sanity_checks)
#      63         y = tf.argmax(model_fn(x), 1)
#      64
# ---> 65     grad = compute_gradient(model_fn, loss_fn, x, y, targeted)
#      66
#      67     optimal_perturbation = optimize_linear(grad, eps, norm)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/cleverhans/tf2/utils.py", line 187, in compute_gradient  *
#         loss = loss_fn(labels=y, logits=model_fn(x))
#
#     ValueError: `labels.shape` must equal `logits.shape` except for the last dimension. Received: labels.shape=(128, 32, 2) and logits.shape=(128, 10, 32, 2)

# %%
tyd

# %%
mim1.X_train.shape
# Out:
# (1212, 10, 32, 2)

# %%
mim1.model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None,
#          [-5.72659671e-01,  7.93412626e-01],
#          [-5.33875108e-01,  8.11860263e-01],
#          [-4.62914765e-01,  8.27249467e-01],
#          [-2.51277149e-01,  8.07804525e-01],
#          [-3.75081271e-01,  8.68293285e-01],
#          [-2.27343976e-01,  8.30025375e-01],
#          [-1.29747897e-01,  7.90322423e-01],
#          [-4.57620509e-02,  8.71791482e-01],
#          [ 6.22143485e-02,  8.45220387e-01],
#          [ 7.12081119e-02,  8.14740479e-01],
#          [ 2.35207573e-01,  8.52485955e-01],
#          [ 1.98066477e-02,  8.55914772e-01],
#          [ 2.40507171e-01,  8.84263635e-01],
#          [ 2.43327275e-01,  7.84987032e-01],
#          [ 3.04695934e-01,  8.61408889e-01],
#          [ 3.23970675e-01,  9.29735482e-01],
#          [ 4.85468179e-01,  7.43573964e-01],
#          [ 4.08002228e-01,  7.98266351e-01],
#          [ 5.21332264e-01,  7.06658542e-01],
#          [ 4.65809077e-01,  7.19433010e-01]]]], dtype=float32)

# %% [markdown]
# ## MIST

# %%
mis1 = MIST(k = 500 , rate = 1/2 ,
                      SNR_dB_start_Eb = -1 ,
                      SNR_dB_stop_Eb = 7 ,
                      SNR_points = 9 ,
                      n_samples = 10 , 
                      train_batch = 1024,
                      test_batch = 1024,
                      g1=[1,1,1],
                      g2=[1,0,1],)

print("training aghl")
mis1.train_gpu(epochs =100,batch_size=1024 )
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(mis1,clean_limit=1000)

# %%
#mim1.train_gpu(epochs =17,batch_size=100 ,compile = True, get_data_build =True,MLP_DroupOut = True)
# Out:
#   File "<ipython-input-6-cb562cfe2158>", line 1
#     mim.train_gpu(epochs =17,batch_size=100 ,compile = True, get_data_build =True,MLP_DroupOut = True))
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
a1.train_gpu(epochs =100,batch_size=1024 )

# %%
mis1.train(epochs = 18 , batch_size=1024 ,MIST_train = True , get_data_build =True)

# %%
mis1 = MIST()
mis1.train(epochs = 9)
# mis1.X_train

# %%
mis1.save("/content/gdrive/MyDrive/proj")
# Out:
# train data shape saved
# train data saved

# %% [markdown]
# todo => load for mist

# %%
a = MIST.load_from_dir("/content/gdrive/MyDrive/proj",mis1.data_path)

# %%
save(mis1,'/content/gdrive/MyDrive/proj/mist2')
# Out:
# train data shape saved
# train data saved

# %%
a1 = aphl("/content/gdrive/MyDrive/projects/RML2016.10a/",num_train_limit = 50000)
print("training aghl")
a1.train_gpu(epochs =100,batch_size=1024 )
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(a1,clean_limit=1000)
# Out:
# training aghl
# Epoch 1/100
# 30/30 - 3s - loss: 2.2948 - accuracy: 0.1512 - val_loss: 2.1307 - val_accuracy: 0.2115 - 3s/epoch - 105ms/step
# Epoch 2/100
# 30/30 - 2s - loss: 2.0469 - accuracy: 0.2309 - val_loss: 1.9879 - val_accuracy: 0.2580 - 2s/epoch - 59ms/step
# Epoch 3/100
# 30/30 - 2s - loss: 1.9305 - accuracy: 0.2794 - val_loss: 1.8952 - val_accuracy: 0.2906 - 2s/epoch - 60ms/step
# Epoch 4/100
# 30/30 - 2s - loss: 1.8520 - accuracy: 0.2978 - val_loss: 1.8349 - val_accuracy: 0.3079 - 2s/epoch - 59ms/step
# Epoch 5/100
# 30/30 - 2s - loss: 1.7968 - accuracy: 0.3250 - val_loss: 1.8054 - val_accuracy: 0.3257 - 2s/epoch - 60ms/step
# Epoch 6/100
# 30/30 - 2s - loss: 1.7492 - accuracy: 0.3520 - val_loss: 1.7360 - val_accuracy: 0.3629 - 2s/epoch - 60ms/step
# Epoch 7/100
# 30/30 - 2s - loss: 1.6878 - accuracy: 0.3778 - val_loss: 1.6852 - val_accuracy: 0.3780 - 2s/epoch - 60ms/step
# Epoch 8/100
# 30/30 - 2s - loss: 1.6269 - accuracy: 0.4031 - val_loss: 1.6173 - val_accuracy: 0.3956 - 2s/epoch - 60ms/step
# Epoch 9/100
# 30/30 - 2s - loss: 1.5703 - accuracy: 0.4194 - val_loss: 1.5930 - val_accuracy: 0.4114 - 2s/epoch - 60ms/step
# Epoch 10/100
# 30/30 - 2s - loss: 1.5591 - accuracy: 0.4215 - val_loss: 1.5488 - val_accuracy: 0.4119 - 2s/epoch - 60ms/step
# Epoch 11/100
# 30/30 - 2s - loss: 1.4987 - accuracy: 0.4423 - val_loss: 1.5283 - val_accuracy: 0.4351 - 2s/epoch - 71ms/step
# Epoch 12/100
# 30/30 - 2s - loss: 1.4737 - accuracy: 0.4485 - val_loss: 1.4799 - val_accuracy: 0.4512 - 2s/epoch - 60ms/step
# Epoch 13/100
# 30/30 - 2s - loss: 1.4450 - accuracy: 0.4561 - val_loss: 1.4976 - val_accuracy: 0.4388 - 2s/epoch - 71ms/step
# Epoch 14/100
# 30/30 - 2s - loss: 1.4176 - accuracy: 0.4707 - val_loss: 1.4539 - val_accuracy: 0.4534 - 2s/epoch - 63ms/step
# Epoch 15/100
# 30/30 - 2s - loss: 1.3997 - accuracy: 0.4768 - val_loss: 1.4149 - val_accuracy: 0.4679 - 2s/epoch - 71ms/step
# Epoch 16/100
# 30/30 - 2s - loss: 1.3687 - accuracy: 0.4872 - val_loss: 1.4313 - val_accuracy: 0.4620 - 2s/epoch - 60ms/step
# Epoch 17/100
# 30/30 - 2s - loss: 1.3500 - accuracy: 0.4948 - val_loss: 1.3855 - val_accuracy: 0.4845 - 2s/epoch - 60ms/step
# Epoch 18/100
# 30/30 - 2s - loss: 1.3323 - accuracy: 0.4975 - val_loss: 1.3513 - val_accuracy: 0.4919 - 2s/epoch - 61ms/step
# Epoch 19/100
# 30/30 - 2s - loss: 1.2989 - accuracy: 0.5161 - val_loss: 1.3332 - val_accuracy: 0.4996 - 2s/epoch - 60ms/step
# Epoch 20/100
# 30/30 - 2s - loss: 1.2896 - accuracy: 0.5196 - val_loss: 1.3404 - val_accuracy: 0.4968 - 2s/epoch - 71ms/step
# Epoch 21/100
# 30/30 - 2s - loss: 1.2673 - accuracy: 0.5288 - val_loss: 1.3046 - val_accuracy: 0.5070 - 2s/epoch - 71ms/step
# Epoch 22/100
# 30/30 - 2s - loss: 1.2411 - accuracy: 0.5385 - val_loss: 1.3024 - val_accuracy: 0.5066 - 2s/epoch - 63ms/step
# Epoch 23/100
# 30/30 - 2s - loss: 1.2471 - accuracy: 0.5312 - val_loss: 1.2690 - val_accuracy: 0.5245 - 2s/epoch - 61ms/step
# Epoch 24/100
# 30/30 - 2s - loss: 1.2244 - accuracy: 0.5413 - val_loss: 1.2581 - val_accuracy: 0.5287 - 2s/epoch - 60ms/step
# Epoch 25/100
# 30/30 - 2s - loss: 1.2034 - accuracy: 0.5510 - val_loss: 1.2603 - val_accuracy: 0.5132 - 2s/epoch - 60ms/step
# Epoch 26/100
# 30/30 - 2s - loss: 1.1828 - accuracy: 0.5588 - val_loss: 1.2551 - val_accuracy: 0.5301 - 2s/epoch - 60ms/step
# Epoch 27/100
# 30/30 - 2s - loss: 1.2021 - accuracy: 0.5476 - val_loss: 1.2327 - val_accuracy: 0.5375 - 2s/epoch - 71ms/step
# Epoch 28/100
# 30/30 - 2s - loss: 1.1662 - accuracy: 0.5671 - val_loss: 1.2089 - val_accuracy: 0.5444 - 2s/epoch - 59ms/step
# Epoch 29/100
# 30/30 - 2s - loss: 1.1477 - accuracy: 0.5742 - val_loss: 1.2085 - val_accuracy: 0.5483 - 2s/epoch - 60ms/step
# Epoch 30/100
# 30/30 - 2s - loss: 1.1551 - accuracy: 0.5688 - val_loss: 1.2097 - val_accuracy: 0.5479 - 2s/epoch - 60ms/step
# Epoch 31/100
# 30/30 - 2s - loss: 1.1386 - accuracy: 0.5768 - val_loss: 1.1827 - val_accuracy: 0.5531 - 2s/epoch - 63ms/step
# Epoch 32/100
# 30/30 - 2s - loss: 1.1291 - accuracy: 0.5805 - val_loss: 1.2053 - val_accuracy: 0.5512 - 2s/epoch - 61ms/step
# Epoch 33/100
# 30/30 - 2s - loss: 1.1242 - accuracy: 0.5823 - val_loss: 1.1863 - val_accuracy: 0.5575 - 2s/epoch - 60ms/step
# Epoch 34/100
# 30/30 - 2s - loss: 1.1101 - accuracy: 0.5872 - val_loss: 1.1683 - val_accuracy: 0.5656 - 2s/epoch - 60ms/step
# Epoch 35/100
# 30/30 - 2s - loss: 1.1035 - accuracy: 0.5896 - val_loss: 1.1743 - val_accuracy: 0.5684 - 2s/epoch - 60ms/step
# Epoch 36/100
# 30/30 - 2s - loss: 1.0946 - accuracy: 0.5928 - val_loss: 1.1881 - val_accuracy: 0.5594 - 2s/epoch - 60ms/step
# Epoch 37/100
# 30/30 - 2s - loss: 1.0875 - accuracy: 0.5974 - val_loss: 1.1480 - val_accuracy: 0.5746 - 2s/epoch - 60ms/step
# Epoch 38/100
# 30/30 - 2s - loss: 1.0766 - accuracy: 0.6006 - val_loss: 1.1579 - val_accuracy: 0.5699 - 2s/epoch - 60ms/step
# Epoch 39/100
# 30/30 - 2s - loss: 1.0698 - accuracy: 0.6004 - val_loss: 1.1545 - val_accuracy: 0.5702 - 2s/epoch - 60ms/step
# Epoch 40/100
# 30/30 - 2s - loss: 1.0770 - accuracy: 0.5969 - val_loss: 1.1752 - val_accuracy: 0.5652 - 2s/epoch - 60ms/step
# Epoch 41/100
# 30/30 - 2s - loss: 1.0633 - accuracy: 0.6044 - val_loss: 1.1360 - val_accuracy: 0.5713 - 2s/epoch - 60ms/step
# Epoch 42/100
# 30/30 - 2s - loss: 1.0501 - accuracy: 0.6074 - val_loss: 1.1312 - val_accuracy: 0.5766 - 2s/epoch - 60ms/step
# Epoch 43/100
# 30/30 - 2s - loss: 1.0510 - accuracy: 0.6049 - val_loss: 1.1131 - val_accuracy: 0.5876 - 2s/epoch - 70ms/step
# Epoch 44/100
# 30/30 - 2s - loss: 1.0480 - accuracy: 0.6089 - val_loss: 1.1212 - val_accuracy: 0.5814 - 2s/epoch - 61ms/step
# Epoch 45/100
# 30/30 - 2s - loss: 1.0486 - accuracy: 0.6056 - val_loss: 1.1396 - val_accuracy: 0.5703 - 2s/epoch - 60ms/step
# Epoch 46/100
# 30/30 - 2s - loss: 1.0487 - accuracy: 0.6101 - val_loss: 1.1160 - val_accuracy: 0.5799 - 2s/epoch - 60ms/step
# Epoch 47/100
# 30/30 - 2s - loss: 1.0284 - accuracy: 0.6159 - val_loss: 1.0974 - val_accuracy: 0.5908 - 2s/epoch - 60ms/step
# Epoch 48/100
# 30/30 - 2s - loss: 1.0176 - accuracy: 0.6210 - val_loss: 1.1121 - val_accuracy: 0.5843 - 2s/epoch - 61ms/step
# Epoch 49/100
# 30/30 - 2s - loss: 1.0289 - accuracy: 0.6141 - val_loss: 1.1144 - val_accuracy: 0.5865 - 2s/epoch - 59ms/step
# Epoch 50/100
# 30/30 - 2s - loss: 1.0119 - accuracy: 0.6197 - val_loss: 1.0964 - val_accuracy: 0.5867 - 2s/epoch - 60ms/step
# Epoch 51/100
# 30/30 - 2s - loss: 1.0103 - accuracy: 0.6222 - val_loss: 1.0989 - val_accuracy: 0.5900 - 2s/epoch - 71ms/step
# Epoch 52/100
# 30/30 - 2s - loss: 1.0135 - accuracy: 0.6213 - val_loss: 1.1031 - val_accuracy: 0.5903 - 2s/epoch - 60ms/step
# Epoch 53/100
# 30/30 - 2s - loss: 1.0102 - accuracy: 0.6202 - val_loss: 1.0906 - val_accuracy: 0.5992 - 2s/epoch - 60ms/step
# Epoch 54/100
# 30/30 - 2s - loss: 0.9967 - accuracy: 0.6294 - val_loss: 1.1149 - val_accuracy: 0.5756 - 2s/epoch - 59ms/step
# Epoch 55/100
# 30/30 - 2s - loss: 1.0289 - accuracy: 0.6148 - val_loss: 1.0953 - val_accuracy: 0.5907 - 2s/epoch - 59ms/step
# Epoch 56/100
# 30/30 - 2s - loss: 0.9931 - accuracy: 0.6285 - val_loss: 1.1123 - val_accuracy: 0.5796 - 2s/epoch - 72ms/step
# Epoch 57/100
# 30/30 - 2s - loss: 0.9989 - accuracy: 0.6277 - val_loss: 1.0891 - val_accuracy: 0.5902 - 2s/epoch - 62ms/step
# Epoch 58/100
# 30/30 - 2s - loss: 0.9845 - accuracy: 0.6318 - val_loss: 1.0870 - val_accuracy: 0.5939 - 2s/epoch - 60ms/step
# Epoch 59/100
# 30/30 - 2s - loss: 1.0023 - accuracy: 0.6219 - val_loss: 1.0937 - val_accuracy: 0.5969 - 2s/epoch - 60ms/step
# Epoch 60/100
# 30/30 - 2s - loss: 0.9903 - accuracy: 0.6298 - val_loss: 1.1060 - val_accuracy: 0.5861 - 2s/epoch - 60ms/step
# Epoch 61/100
# 30/30 - 2s - loss: 0.9798 - accuracy: 0.6342 - val_loss: 1.0842 - val_accuracy: 0.5893 - 2s/epoch - 59ms/step
# Epoch 62/100
# 30/30 - 2s - loss: 0.9941 - accuracy: 0.6257 - val_loss: 1.0987 - val_accuracy: 0.5945 - 2s/epoch - 60ms/step
# Epoch 63/100
# 30/30 - 2s - loss: 0.9772 - accuracy: 0.6351 - val_loss: 1.1323 - val_accuracy: 0.5842 - 2s/epoch - 59ms/step
# Epoch 64/100
# 30/30 - 2s - loss: 0.9921 - accuracy: 0.6272 - val_loss: 1.1451 - val_accuracy: 0.5754 - 2s/epoch - 59ms/step
# Epoch 65/100
# 30/30 - 2s - loss: 0.9870 - accuracy: 0.6323 - val_loss: 1.0950 - val_accuracy: 0.5943 - 2s/epoch - 60ms/step
# Epoch 66/100
# 30/30 - 2s - loss: 0.9708 - accuracy: 0.6372 - val_loss: 1.0730 - val_accuracy: 0.5960 - 2s/epoch - 60ms/step
# Epoch 67/100
# 30/30 - 2s - loss: 0.9657 - accuracy: 0.6390 - val_loss: 1.1220 - val_accuracy: 0.5816 - 2s/epoch - 60ms/step
# Epoch 68/100
# 30/30 - 2s - loss: 0.9725 - accuracy: 0.6377 - val_loss: 1.0762 - val_accuracy: 0.6008 - 2s/epoch - 60ms/step
# Epoch 69/100
# 30/30 - 2s - loss: 0.9640 - accuracy: 0.6398 - val_loss: 1.1144 - val_accuracy: 0.5886 - 2s/epoch - 60ms/step
# Epoch 70/100
# 30/30 - 2s - loss: 0.9599 - accuracy: 0.6422 - val_loss: 1.0986 - val_accuracy: 0.5972 - 2s/epoch - 71ms/step
# Epoch 71/100
# 30/30 - 2s - loss: 0.9498 - accuracy: 0.6467 - val_loss: 1.0679 - val_accuracy: 0.6004 - 2s/epoch - 63ms/step
# Epoch 72/100
# 30/30 - 2s - loss: 0.9468 - accuracy: 0.6503 - val_loss: 1.1201 - val_accuracy: 0.5798 - 2s/epoch - 70ms/step
# Epoch 73/100
# 30/30 - 2s - loss: 0.9518 - accuracy: 0.6450 - val_loss: 1.0727 - val_accuracy: 0.6040 - 2s/epoch - 60ms/step
# Epoch 74/100
# 30/30 - 2s - loss: 0.9391 - accuracy: 0.6526 - val_loss: 1.0753 - val_accuracy: 0.5978 - 2s/epoch - 60ms/step
# Epoch 75/100
# 30/30 - 2s - loss: 0.9528 - accuracy: 0.6467 - val_loss: 1.1199 - val_accuracy: 0.5827 - 2s/epoch - 60ms/step
# Epoch 76/100
# 30/30 - 2s - loss: 0.9536 - accuracy: 0.6444 - val_loss: 1.0921 - val_accuracy: 0.5929 - 2s/epoch - 60ms/step
# Epoch 77/100
# 30/30 - 2s - loss: 0.9503 - accuracy: 0.6458 - val_loss: 1.0947 - val_accuracy: 0.5998 - 2s/epoch - 70ms/step
# Epoch 78/100
# 30/30 - 2s - loss: 0.9309 - accuracy: 0.6550 - val_loss: 1.0888 - val_accuracy: 0.5957 - 2s/epoch - 60ms/step
# Epoch 79/100
# 30/30 - 2s - loss: 0.9213 - accuracy: 0.6590 - val_loss: 1.0924 - val_accuracy: 0.5943 - 2s/epoch - 60ms/step
# Epoch 80/100
# 30/30 - 2s - loss: 0.9245 - accuracy: 0.6576 - val_loss: 1.0809 - val_accuracy: 0.6018 - 2s/epoch - 60ms/step
# Epoch 81/100
# 30/30 - 2s - loss: 0.9239 - accuracy: 0.6570 - val_loss: 1.0765 - val_accuracy: 0.6047 - 2s/epoch - 60ms/step
# Epoch 82/100
# 30/30 - 2s - loss: 0.9305 - accuracy: 0.6557 - val_loss: 1.0698 - val_accuracy: 0.6071 - 2s/epoch - 60ms/step
# Epoch 83/100
# 30/30 - 2s - loss: 0.9166 - accuracy: 0.6607 - val_loss: 1.1021 - val_accuracy: 0.5963 - 2s/epoch - 60ms/step
# Epoch 84/100
# 30/30 - 2s - loss: 0.9196 - accuracy: 0.6571 - val_loss: 1.0928 - val_accuracy: 0.5925 - 2s/epoch - 59ms/step
# Epoch 85/100
# 30/30 - 2s - loss: 0.9224 - accuracy: 0.6565 - val_loss: 1.1001 - val_accuracy: 0.6000 - 2s/epoch - 59ms/step
# Epoch 86/100
# 30/30 - 2s - loss: 0.9124 - accuracy: 0.6615 - val_loss: 1.0789 - val_accuracy: 0.6051 - 2s/epoch - 60ms/step
# Epoch 87/100
# 30/30 - 2s - loss: 0.9090 - accuracy: 0.6665 - val_loss: 1.0800 - val_accuracy: 0.6007 - 2s/epoch - 60ms/step
# Epoch 88/100
# 30/30 - 2s - loss: 0.9114 - accuracy: 0.6618 - val_loss: 1.0998 - val_accuracy: 0.5942 - 2s/epoch - 60ms/step
# Epoch 89/100
# 30/30 - 2s - loss: 0.9298 - accuracy: 0.6549 - val_loss: 1.1274 - val_accuracy: 0.5908 - 2s/epoch - 60ms/step
# Epoch 90/100
# 30/30 - 2s - loss: 0.8951 - accuracy: 0.6694 - val_loss: 1.0985 - val_accuracy: 0.6020 - 2s/epoch - 60ms/step
# Epoch 91/100
# 30/30 - 2s - loss: 0.8975 - accuracy: 0.6653 - val_loss: 1.0957 - val_accuracy: 0.5972 - 2s/epoch - 71ms/step
# Epoch 92/100
# 30/30 - 2s - loss: 0.8979 - accuracy: 0.6653 - val_loss: 1.1045 - val_accuracy: 0.6002 - 2s/epoch - 59ms/step
# Epoch 93/100
# 30/30 - 2s - loss: 0.9028 - accuracy: 0.6653 - val_loss: 1.0991 - val_accuracy: 0.5925 - 2s/epoch - 62ms/step
# Epoch 94/100
# 30/30 - 2s - loss: 0.8843 - accuracy: 0.6737 - val_loss: 1.0858 - val_accuracy: 0.6039 - 2s/epoch - 60ms/step
# Epoch 95/100
# 30/30 - 2s - loss: 0.8710 - accuracy: 0.6785 - val_loss: 1.0960 - val_accuracy: 0.6007 - 2s/epoch - 59ms/step
# Epoch 96/100
# 30/30 - 2s - loss: 0.8751 - accuracy: 0.6765 - val_loss: 1.1127 - val_accuracy: 0.5986 - 2s/epoch - 59ms/step
# Epoch 97/100
# 30/30 - 2s - loss: 0.8928 - accuracy: 0.6670 - val_loss: 1.0929 - val_accuracy: 0.6012 - 2s/epoch - 60ms/step
# Epoch 98/100
# 30/30 - 2s - loss: 0.8640 - accuracy: 0.6808 - val_loss: 1.1036 - val_accuracy: 0.5937 - 2s/epoch - 60ms/step
# Epoch 99/100
# 30/30 - 2s - loss: 0.8622 - accuracy: 0.6826 - val_loss: 1.1022 - val_accuracy: 0.6035 - 2s/epoch - 59ms/step
# Epoch 100/100
# 30/30 - 2s - loss: 0.8624 - accuracy: 0.6818 - val_loss: 1.1007 - val_accuracy: 0.6048 - 2s/epoch - 59ms/step
# attack
# getting clean data from model
# (234, 128, 2, 128)
# (7, 128, 2, 128)
# Train model with adversarial training
# 29952/50000 [================>.............] - ETA: 1s - loss: 0.0819Evaluate on clean and adversarial data
#   896/10000 [=>............................] - ETA: 23saphl
# test acc on clean examples (%): 49.107
# test acc on FGM adversarial examples (%): 42.522
# test acc on PGD adversarial examples (%): 21.763

# %%
dict(a=10)
# Out:
# {'a': 10}

# %%
print(d.acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-3a0b724c8fe8> in <module>()
# ----> 1 print(d.acc)
#
# AttributeError: 'NoneType' object has no attribute 'acc'

# %% [markdown]
# # attack

# %%
class Attack_handler:
    def __init__(self,nb_epochs= 1,eps = 0.05, adv_train = False ,batch = 128 ):
       for i,(key,value) in enumerate(locals().items()):
          if i < 1 : continue
          setattr(self,key,value)

    
    def attack(self,a,clean_limit=100):
      FLAGS = {"nb_epochs": self.nb_epochs ,"eps": self.eps,"adv_train": self.adv_train}
      self.start_attack(a,FLAGS,self.batch,clean_limit)


    @staticmethod
    def start_attack(a , FLAGS = {"nb_epochs": 1,"eps": 0.05,"adv_train": False} ,batch = 128,clean_limit =100):
        lim = int(a.X_train.shape[0]/128)
        train = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in [a.X_train,a.y_train]]

        def get_clean_data(a,limit):
              pred = a.model.predict(a.X_train)
              diff = np.mean(np.abs(pred - a.y_train),axis=-1)
              for i in range (len(a.X_train.shape)-3):
                  diff = np.mean(diff,axis=-1)
              best_answer_index = np.argsort(diff)
              return [a.X_train[best_answer_index][:limit] , a.y_train[best_answer_index][:limit]]
        print("getting clean data from model")
        
        clean = get_clean_data(a,clean_limit)
        lim = int(clean[0].shape[0]/128)
        test = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in clean]
        data = EasyDict(train=train, test=test)
        print(data.train[0].shape)
        print(data.test[0].shape)
        # Load training and test data
        model = a.model
        loss_object =tf.keras.losses.MeanSquaredError()
        optimizer = tf.optimizers.Adam(learning_rate=0.001)

        # Metrics to track the different accuracies.
        train_loss = tf.metrics.Mean(name="train_loss")
        test_acc = tf.keras.metrics.CategoricalAccuracy()
        test_acc_fgsm = tf.keras.metrics.CategoricalAccuracy()
        test_acc_pgd = tf.keras.metrics.CategoricalAccuracy()

        @tf.function
        def train_step(x, y):
            with tf.GradientTape() as tape:
                predictions = model(x)
                loss = loss_object(y, predictions)
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            train_loss(loss)

        print("Train model with adversarial training")
        # Train model with adversarial training
        for epoch in range(FLAGS["nb_epochs"]):
            # keras like display of progress
            progress_bar_train = tf.keras.utils.Progbar(50000)
            for i in range(data.train[0].shape[0]):
                if FLAGS['adv_train']:
                    # Replace clean example with adversarial example for adversarial training
                    x = projected_gradient_descent(model, data.train[0][i,:], FLAGS['eps'], 0.01, 40, np.inf)
                train_step(data.train[0][i,:], data.train[1][i,:])
                progress_bar_train.add(data.train[0][i,:].shape[0], values=[("loss", train_loss.result())])

        print("Evaluate on clean and adversarial data")

        
        # Evaluate on clean and adversarial data

        progress_bar_test = tf.keras.utils.Progbar(10000)
        for i in range(data.test[0].shape[0]):
            y_pred = model(data.test[0][i,:])
            test_acc(data.test[1][i,:], y_pred)

            x_fgm = fast_gradient_method(model, data.test[0][i,:], FLAGS['eps'], np.inf)
            y_pred_fgm = model(x_fgm)
            test_acc_fgsm(data.test[1][i,:], y_pred_fgm)

            x_pgd = projected_gradient_descent(model, data.test[0][i,:], FLAGS['eps'], 0.01, 40, np.inf)
            y_pred_pgd = model(x_pgd)
            test_acc_pgd(data.test[1][i,:], y_pred_pgd)

            progress_bar_test.add(data.test[0][i,:].shape[0])
        
        print(a.name)    

        print(
            "test acc on clean examples (%): {:.3f}".format(test_acc.result() * 100)
        )
        print(
            "test acc on FGM adversarial examples (%): {:.3f}".format(
                test_acc_fgsm.result() * 100
            )
        )
        print(
            "test acc on PGD adversarial examples (%): {:.3f}".format(
                test_acc_pgd.result() * 100
            )
        )

        return dict(acc = test_acc.result(),acc_FGM = test_acc_fgsm.result(),acc_pdg = test_acc_pgd.result())

# %% [markdown]
# ## git

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/proj/.git/

# %%
# !git config --global user.email "this.email.will.use.as.database@gmail.com"

# %%
# !git config --global user.name "itsparsa"

# %%
# !git commit -m 'lib added from colab direetly'
# Out:
# On branch master
#
# Initial commit
#
# Untracked files:
# 	__init__.py
# 	mist/
# 	mist0/
# 	mist1/
# 	mist2/
# 	mist3/
# 	mist4/
# 	misttrain.npz
# 	misttrain_shape.npz
#
# nothing added to commit but untracked files present

# %%
# !git remote rm origin

# %%
# !!git remote add origin https://itsparsa:Google1375@github.com/itsparsa/communication_sec_.git
# Out:
# []

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://itsparsa:Google1375@github.com/itsparsa/communication_sec_.git'
