# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## start

# %% [markdown]
# just paste the locataction you allocated for the google drive file, that you have been created as shourcut link based on readme description

# %%
proj_path = "/content/gdrive/MyDrive/projects"

# %%
import os 
import sys
os.chdir('/content/gdrive/MyDrive/projects')
sys.path.append('/content/gdrive/MyDrive/Models')
from attack.cleverhans_attack import *
from autoencoder import aphl 
from deepmimo import Deep_MIMO
from mist import MIST
from pe import PE
import numpy as np

# %% [markdown]
# ## aphl

# %%
a1 = aphl("/content/gdrive/MyDrive/projects/RML2016.10a/",num_train_limit = 10000)
print("training aghl")
a1.train_gpu(epochs =50,batch_size=1024, get_data_build =True )
# Out:
# training aghl
# Epoch 1/5
# 6/6 - 13s - loss: 2.3414 - categorical_crossentropy: 2.3414 - val_loss: 2.1892 - val_categorical_crossentropy: 2.1892 - 13s/epoch - 2s/step
# Epoch 2/5
# 6/6 - 0s - loss: 2.1080 - categorical_crossentropy: 2.1080 - val_loss: 2.0208 - val_categorical_crossentropy: 2.0208 - 399ms/epoch - 66ms/step
# Epoch 3/5
# 6/6 - 0s - loss: 1.9690 - categorical_crossentropy: 1.9690 - val_loss: 1.8992 - val_categorical_crossentropy: 1.8992 - 406ms/epoch - 68ms/step
# Epoch 4/5
# 6/6 - 0s - loss: 1.8710 - categorical_crossentropy: 1.8710 - val_loss: 1.8174 - val_categorical_crossentropy: 1.8174 - 408ms/epoch - 68ms/step
# Epoch 5/5
# 6/6 - 0s - loss: 1.7787 - categorical_crossentropy: 1.7787 - val_loss: 1.7200 - val_categorical_crossentropy: 1.7200 - 402ms/epoch - 67ms/step

# %%
a1.train_gpu(epochs =50,batch_size=1024,get_data_build =False )
# Out:
# Epoch 1/50
# 6/6 - 1s - loss: 3.9287 - categorical_crossentropy: 3.9287 - val_loss: 3.5002 - val_categorical_crossentropy: 3.5002 - 527ms/epoch - 88ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 3.2617 - categorical_crossentropy: 3.2617 - val_loss: 2.9285 - val_categorical_crossentropy: 2.9285 - 397ms/epoch - 66ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 2.7923 - categorical_crossentropy: 2.7923 - val_loss: 2.6029 - val_categorical_crossentropy: 2.6029 - 481ms/epoch - 80ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 2.5240 - categorical_crossentropy: 2.5240 - val_loss: 2.4037 - val_categorical_crossentropy: 2.4037 - 475ms/epoch - 79ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 2.3560 - categorical_crossentropy: 2.3560 - val_loss: 2.2909 - val_categorical_crossentropy: 2.2909 - 398ms/epoch - 66ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 2.2695 - categorical_crossentropy: 2.2695 - val_loss: 2.2403 - val_categorical_crossentropy: 2.2403 - 402ms/epoch - 67ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 2.2345 - categorical_crossentropy: 2.2345 - val_loss: 2.2238 - val_categorical_crossentropy: 2.2238 - 401ms/epoch - 67ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 2.2211 - categorical_crossentropy: 2.2211 - val_loss: 2.2139 - val_categorical_crossentropy: 2.2139 - 401ms/epoch - 67ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 2.2102 - categorical_crossentropy: 2.2102 - val_loss: 2.2010 - val_categorical_crossentropy: 2.2010 - 414ms/epoch - 69ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 2.1958 - categorical_crossentropy: 2.1958 - val_loss: 2.1855 - val_categorical_crossentropy: 2.1855 - 392ms/epoch - 65ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 2.1804 - categorical_crossentropy: 2.1804 - val_loss: 2.1694 - val_categorical_crossentropy: 2.1694 - 398ms/epoch - 66ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 2.1648 - categorical_crossentropy: 2.1648 - val_loss: 2.1540 - val_categorical_crossentropy: 2.1540 - 478ms/epoch - 80ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 2.1503 - categorical_crossentropy: 2.1503 - val_loss: 2.1394 - val_categorical_crossentropy: 2.1394 - 399ms/epoch - 67ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 2.1369 - categorical_crossentropy: 2.1369 - val_loss: 2.1259 - val_categorical_crossentropy: 2.1259 - 393ms/epoch - 66ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 2.1244 - categorical_crossentropy: 2.1244 - val_loss: 2.1138 - val_categorical_crossentropy: 2.1138 - 400ms/epoch - 67ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 2.1129 - categorical_crossentropy: 2.1129 - val_loss: 2.1030 - val_categorical_crossentropy: 2.1030 - 397ms/epoch - 66ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 2.1025 - categorical_crossentropy: 2.1025 - val_loss: 2.0928 - val_categorical_crossentropy: 2.0928 - 480ms/epoch - 80ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 2.0926 - categorical_crossentropy: 2.0926 - val_loss: 2.0836 - val_categorical_crossentropy: 2.0836 - 400ms/epoch - 67ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 2.0833 - categorical_crossentropy: 2.0833 - val_loss: 2.0755 - val_categorical_crossentropy: 2.0755 - 480ms/epoch - 80ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 2.0751 - categorical_crossentropy: 2.0751 - val_loss: 2.0682 - val_categorical_crossentropy: 2.0682 - 475ms/epoch - 79ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 2.0679 - categorical_crossentropy: 2.0679 - val_loss: 2.0619 - val_categorical_crossentropy: 2.0619 - 390ms/epoch - 65ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 2.0618 - categorical_crossentropy: 2.0618 - val_loss: 2.0565 - val_categorical_crossentropy: 2.0565 - 479ms/epoch - 80ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 2.0566 - categorical_crossentropy: 2.0566 - val_loss: 2.0520 - val_categorical_crossentropy: 2.0520 - 403ms/epoch - 67ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 2.0523 - categorical_crossentropy: 2.0523 - val_loss: 2.0482 - val_categorical_crossentropy: 2.0482 - 396ms/epoch - 66ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 2.0486 - categorical_crossentropy: 2.0486 - val_loss: 2.0452 - val_categorical_crossentropy: 2.0452 - 407ms/epoch - 68ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 2.0456 - categorical_crossentropy: 2.0456 - val_loss: 2.0428 - val_categorical_crossentropy: 2.0428 - 404ms/epoch - 67ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 2.0431 - categorical_crossentropy: 2.0431 - val_loss: 2.0403 - val_categorical_crossentropy: 2.0403 - 478ms/epoch - 80ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 2.0410 - categorical_crossentropy: 2.0410 - val_loss: 2.0383 - val_categorical_crossentropy: 2.0383 - 475ms/epoch - 79ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 2.0393 - categorical_crossentropy: 2.0393 - val_loss: 2.0366 - val_categorical_crossentropy: 2.0366 - 393ms/epoch - 65ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 2.0379 - categorical_crossentropy: 2.0379 - val_loss: 2.0353 - val_categorical_crossentropy: 2.0353 - 486ms/epoch - 81ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 2.0367 - categorical_crossentropy: 2.0367 - val_loss: 2.0342 - val_categorical_crossentropy: 2.0342 - 400ms/epoch - 67ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 2.0357 - categorical_crossentropy: 2.0357 - val_loss: 2.0333 - val_categorical_crossentropy: 2.0333 - 482ms/epoch - 80ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 2.0348 - categorical_crossentropy: 2.0348 - val_loss: 2.0326 - val_categorical_crossentropy: 2.0326 - 395ms/epoch - 66ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 2.0341 - categorical_crossentropy: 2.0341 - val_loss: 2.0318 - val_categorical_crossentropy: 2.0318 - 475ms/epoch - 79ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 2.0334 - categorical_crossentropy: 2.0334 - val_loss: 2.0312 - val_categorical_crossentropy: 2.0312 - 475ms/epoch - 79ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 2.0331 - categorical_crossentropy: 2.0331 - val_loss: 2.0309 - val_categorical_crossentropy: 2.0309 - 394ms/epoch - 66ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 2.0324 - categorical_crossentropy: 2.0324 - val_loss: 2.0304 - val_categorical_crossentropy: 2.0304 - 479ms/epoch - 80ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 2.0320 - categorical_crossentropy: 2.0320 - val_loss: 2.0299 - val_categorical_crossentropy: 2.0299 - 475ms/epoch - 79ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 2.0316 - categorical_crossentropy: 2.0316 - val_loss: 2.0295 - val_categorical_crossentropy: 2.0295 - 472ms/epoch - 79ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 2.0313 - categorical_crossentropy: 2.0313 - val_loss: 2.0295 - val_categorical_crossentropy: 2.0295 - 478ms/epoch - 80ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 2.0309 - categorical_crossentropy: 2.0309 - val_loss: 2.0293 - val_categorical_crossentropy: 2.0293 - 393ms/epoch - 66ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 2.0306 - categorical_crossentropy: 2.0306 - val_loss: 2.0288 - val_categorical_crossentropy: 2.0288 - 394ms/epoch - 66ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 2.0305 - categorical_crossentropy: 2.0305 - val_loss: 2.0283 - val_categorical_crossentropy: 2.0283 - 399ms/epoch - 67ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 2.0302 - categorical_crossentropy: 2.0302 - val_loss: 2.0282 - val_categorical_crossentropy: 2.0282 - 399ms/epoch - 67ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 2.0300 - categorical_crossentropy: 2.0300 - val_loss: 2.0284 - val_categorical_crossentropy: 2.0284 - 476ms/epoch - 79ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 2.0298 - categorical_crossentropy: 2.0298 - val_loss: 2.0281 - val_categorical_crossentropy: 2.0281 - 396ms/epoch - 66ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 2.0296 - categorical_crossentropy: 2.0296 - val_loss: 2.0278 - val_categorical_crossentropy: 2.0278 - 399ms/epoch - 66ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 2.0295 - categorical_crossentropy: 2.0295 - val_loss: 2.0278 - val_categorical_crossentropy: 2.0278 - 393ms/epoch - 66ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 2.0293 - categorical_crossentropy: 2.0293 - val_loss: 2.0275 - val_categorical_crossentropy: 2.0275 - 401ms/epoch - 67ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 2.0292 - categorical_crossentropy: 2.0292 - val_loss: 2.0274 - val_categorical_crossentropy: 2.0274 - 470ms/epoch - 78ms/step

# %%
clean  = a1.get_clean_data(256)
a1.metric(clean[1],a1.model(clean[0]))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.565229>

# %%
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.7290148>

# %%
print("attack")
att = Attack_handler(nb_epochs= 100,
                     eps = 0.5,
                     adv_train = True ,
                     batch = 64)
d = att.attack(a1,clean_limit=256)
# Out:
# attack
#  data train [0] (46, 64, 2, 128)
#  data train [1] (46, 64, 11)
#  data test [0] (2, 64, 2, 128)
#  data test [1] (2, 64, 11)
# Train model with adversarial training
#  2944/50000 [>.............................] - ETA: 3:23 - loss: 1.3563Evaluate on clean and adversarial data
# getting clean data from model
# (64, 2, 128)
# (64, 11) (64, 11)
#    64/50000 [..............................] - ETA: 3:37(64, 11) (64, 11)
#   128/50000 [..............................] - ETA: 3:34aphl
# test acc on clean examples categorical_crossentropy : 166.607
# test acc on FGM adversarial examples categorical_crossentropy: 166.607
# test acc on PGD adversarial examples categorical_crossentropy : 166.607

# %% [markdown]
# ## PE

# %%
p1 = PE(proj_path+"/project_3/PE", train_snr = np.arange(20, -4, -2),  limit = 1000, execute=False )
print("training PE")
p1.train_gpu(epochs =100,batch_size=1024 )

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(p1,clean_limit=100)
# Out:
# attack

# %% [markdown]
# ## DEEPMIMO

# %%
mim1 = Deep_MIMO(proj_path+    '/DeepMIMO2',
                                active_BS = 5,
                                user_row_first = 2,
                                user_row_last = 10,
                                bandwidth = 0.05,
                                subcarriers = 64 ,
                                subcarriers_sampling = 1 ,
                                subcarriers_limit = 32,
                                num_paths = 1,
                                num_set_antenna_M = 2,
                                MLP_DroupOut = 0.1)

print("training DEEPMIMO")
mim1.train_gpu(epochs =10,batch_size=1024)
# Out:
# training DEEPMIMO
#
# Basestation 1
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 22803.02it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6912.31it/s]
# Basestation 2
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 10426.83it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 2963.16it/s]
# Basestation 3
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 21315.65it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6704.49it/s]
# Basestation 4
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 8968.10it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 2789.46it/s]
# Basestation 5
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 20320.46it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 7238.06it/s]
# Basestation 1
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 23564.56it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6660.16it/s]
# Basestation 2
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 25824.94it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6776.17it/s]
# Basestation 3
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 25461.79it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6131.80it/s]
# Basestation 4
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 21803.30it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6432.03it/s]
# Basestation 5
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 22189.34it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6685.10it/s]
# (5, 1809, 32)
# (5, 1809, 32)
# Epoch 1/10
# 2/2 - 1s - loss: 0.3518 - mean_absolute_error: 0.5272 - val_loss: 0.2770 - val_mean_absolute_error: 0.4334 - 972ms/epoch - 486ms/step
# Epoch 2/10
# 2/2 - 0s - loss: 0.2735 - mean_absolute_error: 0.4283 - val_loss: 0.2541 - val_mean_absolute_error: 0.4047 - 222ms/epoch - 111ms/step
# Epoch 3/10
# 2/2 - 0s - loss: 0.2452 - mean_absolute_error: 0.3980 - val_loss: 0.2360 - val_mean_absolute_error: 0.3879 - 198ms/epoch - 99ms/step
# Epoch 4/10
# 2/2 - 0s - loss: 0.2240 - mean_absolute_error: 0.3778 - val_loss: 0.2178 - val_mean_absolute_error: 0.3590 - 192ms/epoch - 96ms/step
# Epoch 5/10
# 2/2 - 0s - loss: 0.2018 - mean_absolute_error: 0.3474 - val_loss: 0.2110 - val_mean_absolute_error: 0.3497 - 186ms/epoch - 93ms/step
# Epoch 6/10
# 2/2 - 0s - loss: 0.1896 - mean_absolute_error: 0.3330 - val_loss: 0.2073 - val_mean_absolute_error: 0.3462 - 189ms/epoch - 95ms/step
# Epoch 7/10
# 2/2 - 0s - loss: 0.1801 - mean_absolute_error: 0.3238 - val_loss: 0.2027 - val_mean_absolute_error: 0.3365 - 196ms/epoch - 98ms/step
# Epoch 8/10
# 2/2 - 0s - loss: 0.1700 - mean_absolute_error: 0.3113 - val_loss: 0.1954 - val_mean_absolute_error: 0.3272 - 195ms/epoch - 98ms/step
# Epoch 9/10
# 2/2 - 0s - loss: 0.1594 - mean_absolute_error: 0.2988 - val_loss: 0.1939 - val_mean_absolute_error: 0.3267 - 226ms/epoch - 113ms/step
# Epoch 10/10
# 2/2 - 0s - loss: 0.1527 - mean_absolute_error: 0.2926 - val_loss: 0.1893 - val_mean_absolute_error: 0.3195 - 211ms/epoch - 106ms/step

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 64)

d = att.attack(mim1,clean_limit=128)
# Out:
# attack
#  data train [0] (9, 64, 5, 32, 2)
#  data train [1] (9, 64, 5, 32, 2)
#  data test [0] (1, 64, 5, 32, 2)
#  data test [1] (1, 64, 5, 32, 2)
# Train model with adversarial training
#   512/50000 [..............................] - ETA: 1:36 - loss: -0.0349Evaluate on clean and adversarial data
# getting clean data from model
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-4321ab58157e> in <module>()
#       5                      batch = 64)
#       6
# ----> 7 d = att.attack(mim1,clean_limit=128)
#
# /content/gdrive/MyDrive/Models/attack/cleverhans_attack.py in attack(self, a, clean_limit)
#      23     def attack(self,a,clean_limit=100):
#      24       FLAGS = {"nb_epochs": self.nb_epochs ,"eps": self.eps,"adv_train": self.adv_train}
# ---> 25       self.start_attack(a,FLAGS,self.batch,clean_limit)
#      26
#      27
#
# /content/gdrive/MyDrive/Models/attack/cleverhans_attack.py in start_attack(a, FLAGS, batch, limit)
#      88
#      89         # Evaluate on clean and adversarial data
# ---> 90         print(data.test[0][1,:].shape)
#      91         # print(data.test[1][0,0:2])
#      92         # print(model(data.test[0][0,0:2]))
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %% [markdown]
# ## MIST

# %%
mis1 = MIST(k = 500 , rate = 1/2 ,
                      SNR_dB_start_Eb = -1 ,
                      SNR_dB_stop_Eb = 7 ,
                      SNR_points = 9 ,
                      n_samples = 10 , 
                      train_batch = 1024,
                      test_batch = 1024,
                      g1=[1,1,1],
                      g2=[1,0,1],)

print("training MIST")
mis1.train_gpu(epochs =100,batch_size=1024 )
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(mis1,clean_limit=1000)

# %%
#mim1.train_gpu(epochs =17,batch_size=100 ,compile = True, get_data_build =True,MLP_DroupOut = True)
# Out:
#   File "<ipython-input-6-cb562cfe2158>", line 1
#     mim.train_gpu(epochs =17,batch_size=100 ,compile = True, get_data_build =True,MLP_DroupOut = True))
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
a1.train_gpu(epochs =100,batch_size=1024 )

# %%
mis1.train(epochs = 18 , batch_size=1024 ,MIST_train = True , get_data_build =True)

# %%
mis1 = MIST()
mis1.train(epochs = 9)
# mis1.X_train

# %%
mis1.save("/content/gdrive/MyDrive/proj")
# Out:
# train data shape saved
# train data saved

# %% [markdown]
# todo => load for mist

# %%
a = MIST.load_from_dir("/content/gdrive/MyDrive/proj",mis1.data_path)

# %%
save(mis1,'/content/gdrive/MyDrive/proj/mist2')
# Out:
# train data shape saved
# train data saved

# %%
a1 = aphl("/content/gdrive/MyDrive/projects/RML2016.10a/",num_train_limit = 50000)
print("training aghl")
a1.train_gpu(epochs =100,batch_size=1024 )
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = False ,
                     batch = 128)

d = att.attack(a1,clean_limit=1000)
# Out:
# training aghl
# Epoch 1/100
# 30/30 - 3s - loss: 2.2948 - accuracy: 0.1512 - val_loss: 2.1307 - val_accuracy: 0.2115 - 3s/epoch - 105ms/step
# Epoch 2/100
# 30/30 - 2s - loss: 2.0469 - accuracy: 0.2309 - val_loss: 1.9879 - val_accuracy: 0.2580 - 2s/epoch - 59ms/step
# Epoch 3/100
# 30/30 - 2s - loss: 1.9305 - accuracy: 0.2794 - val_loss: 1.8952 - val_accuracy: 0.2906 - 2s/epoch - 60ms/step
# Epoch 4/100
# 30/30 - 2s - loss: 1.8520 - accuracy: 0.2978 - val_loss: 1.8349 - val_accuracy: 0.3079 - 2s/epoch - 59ms/step
# Epoch 5/100
# 30/30 - 2s - loss: 1.7968 - accuracy: 0.3250 - val_loss: 1.8054 - val_accuracy: 0.3257 - 2s/epoch - 60ms/step
# Epoch 6/100
# 30/30 - 2s - loss: 1.7492 - accuracy: 0.3520 - val_loss: 1.7360 - val_accuracy: 0.3629 - 2s/epoch - 60ms/step
# Epoch 7/100
# 30/30 - 2s - loss: 1.6878 - accuracy: 0.3778 - val_loss: 1.6852 - val_accuracy: 0.3780 - 2s/epoch - 60ms/step
# Epoch 8/100
# 30/30 - 2s - loss: 1.6269 - accuracy: 0.4031 - val_loss: 1.6173 - val_accuracy: 0.3956 - 2s/epoch - 60ms/step
# Epoch 9/100
# 30/30 - 2s - loss: 1.5703 - accuracy: 0.4194 - val_loss: 1.5930 - val_accuracy: 0.4114 - 2s/epoch - 60ms/step
# Epoch 10/100
# 30/30 - 2s - loss: 1.5591 - accuracy: 0.4215 - val_loss: 1.5488 - val_accuracy: 0.4119 - 2s/epoch - 60ms/step
# Epoch 11/100
# 30/30 - 2s - loss: 1.4987 - accuracy: 0.4423 - val_loss: 1.5283 - val_accuracy: 0.4351 - 2s/epoch - 71ms/step
# Epoch 12/100
# 30/30 - 2s - loss: 1.4737 - accuracy: 0.4485 - val_loss: 1.4799 - val_accuracy: 0.4512 - 2s/epoch - 60ms/step
# Epoch 13/100
# 30/30 - 2s - loss: 1.4450 - accuracy: 0.4561 - val_loss: 1.4976 - val_accuracy: 0.4388 - 2s/epoch - 71ms/step
# Epoch 14/100
# 30/30 - 2s - loss: 1.4176 - accuracy: 0.4707 - val_loss: 1.4539 - val_accuracy: 0.4534 - 2s/epoch - 63ms/step
# Epoch 15/100
# 30/30 - 2s - loss: 1.3997 - accuracy: 0.4768 - val_loss: 1.4149 - val_accuracy: 0.4679 - 2s/epoch - 71ms/step
# Epoch 16/100
# 30/30 - 2s - loss: 1.3687 - accuracy: 0.4872 - val_loss: 1.4313 - val_accuracy: 0.4620 - 2s/epoch - 60ms/step
# Epoch 17/100
# 30/30 - 2s - loss: 1.3500 - accuracy: 0.4948 - val_loss: 1.3855 - val_accuracy: 0.4845 - 2s/epoch - 60ms/step
# Epoch 18/100
# 30/30 - 2s - loss: 1.3323 - accuracy: 0.4975 - val_loss: 1.3513 - val_accuracy: 0.4919 - 2s/epoch - 61ms/step
# Epoch 19/100
# 30/30 - 2s - loss: 1.2989 - accuracy: 0.5161 - val_loss: 1.3332 - val_accuracy: 0.4996 - 2s/epoch - 60ms/step
# Epoch 20/100
# 30/30 - 2s - loss: 1.2896 - accuracy: 0.5196 - val_loss: 1.3404 - val_accuracy: 0.4968 - 2s/epoch - 71ms/step
# Epoch 21/100
# 30/30 - 2s - loss: 1.2673 - accuracy: 0.5288 - val_loss: 1.3046 - val_accuracy: 0.5070 - 2s/epoch - 71ms/step
# Epoch 22/100
# 30/30 - 2s - loss: 1.2411 - accuracy: 0.5385 - val_loss: 1.3024 - val_accuracy: 0.5066 - 2s/epoch - 63ms/step
# Epoch 23/100
# 30/30 - 2s - loss: 1.2471 - accuracy: 0.5312 - val_loss: 1.2690 - val_accuracy: 0.5245 - 2s/epoch - 61ms/step
# Epoch 24/100
# 30/30 - 2s - loss: 1.2244 - accuracy: 0.5413 - val_loss: 1.2581 - val_accuracy: 0.5287 - 2s/epoch - 60ms/step
# Epoch 25/100
# 30/30 - 2s - loss: 1.2034 - accuracy: 0.5510 - val_loss: 1.2603 - val_accuracy: 0.5132 - 2s/epoch - 60ms/step
# Epoch 26/100
# 30/30 - 2s - loss: 1.1828 - accuracy: 0.5588 - val_loss: 1.2551 - val_accuracy: 0.5301 - 2s/epoch - 60ms/step
# Epoch 27/100
# 30/30 - 2s - loss: 1.2021 - accuracy: 0.5476 - val_loss: 1.2327 - val_accuracy: 0.5375 - 2s/epoch - 71ms/step
# Epoch 28/100
# 30/30 - 2s - loss: 1.1662 - accuracy: 0.5671 - val_loss: 1.2089 - val_accuracy: 0.5444 - 2s/epoch - 59ms/step
# Epoch 29/100
# 30/30 - 2s - loss: 1.1477 - accuracy: 0.5742 - val_loss: 1.2085 - val_accuracy: 0.5483 - 2s/epoch - 60ms/step
# Epoch 30/100
# 30/30 - 2s - loss: 1.1551 - accuracy: 0.5688 - val_loss: 1.2097 - val_accuracy: 0.5479 - 2s/epoch - 60ms/step
# Epoch 31/100
# 30/30 - 2s - loss: 1.1386 - accuracy: 0.5768 - val_loss: 1.1827 - val_accuracy: 0.5531 - 2s/epoch - 63ms/step
# Epoch 32/100
# 30/30 - 2s - loss: 1.1291 - accuracy: 0.5805 - val_loss: 1.2053 - val_accuracy: 0.5512 - 2s/epoch - 61ms/step
# Epoch 33/100
# 30/30 - 2s - loss: 1.1242 - accuracy: 0.5823 - val_loss: 1.1863 - val_accuracy: 0.5575 - 2s/epoch - 60ms/step
# Epoch 34/100
# 30/30 - 2s - loss: 1.1101 - accuracy: 0.5872 - val_loss: 1.1683 - val_accuracy: 0.5656 - 2s/epoch - 60ms/step
# Epoch 35/100
# 30/30 - 2s - loss: 1.1035 - accuracy: 0.5896 - val_loss: 1.1743 - val_accuracy: 0.5684 - 2s/epoch - 60ms/step
# Epoch 36/100
# 30/30 - 2s - loss: 1.0946 - accuracy: 0.5928 - val_loss: 1.1881 - val_accuracy: 0.5594 - 2s/epoch - 60ms/step
# Epoch 37/100
# 30/30 - 2s - loss: 1.0875 - accuracy: 0.5974 - val_loss: 1.1480 - val_accuracy: 0.5746 - 2s/epoch - 60ms/step
# Epoch 38/100
# 30/30 - 2s - loss: 1.0766 - accuracy: 0.6006 - val_loss: 1.1579 - val_accuracy: 0.5699 - 2s/epoch - 60ms/step
# Epoch 39/100
# 30/30 - 2s - loss: 1.0698 - accuracy: 0.6004 - val_loss: 1.1545 - val_accuracy: 0.5702 - 2s/epoch - 60ms/step
# Epoch 40/100
# 30/30 - 2s - loss: 1.0770 - accuracy: 0.5969 - val_loss: 1.1752 - val_accuracy: 0.5652 - 2s/epoch - 60ms/step
# Epoch 41/100
# 30/30 - 2s - loss: 1.0633 - accuracy: 0.6044 - val_loss: 1.1360 - val_accuracy: 0.5713 - 2s/epoch - 60ms/step
# Epoch 42/100
# 30/30 - 2s - loss: 1.0501 - accuracy: 0.6074 - val_loss: 1.1312 - val_accuracy: 0.5766 - 2s/epoch - 60ms/step
# Epoch 43/100
# 30/30 - 2s - loss: 1.0510 - accuracy: 0.6049 - val_loss: 1.1131 - val_accuracy: 0.5876 - 2s/epoch - 70ms/step
# Epoch 44/100
# 30/30 - 2s - loss: 1.0480 - accuracy: 0.6089 - val_loss: 1.1212 - val_accuracy: 0.5814 - 2s/epoch - 61ms/step
# Epoch 45/100
# 30/30 - 2s - loss: 1.0486 - accuracy: 0.6056 - val_loss: 1.1396 - val_accuracy: 0.5703 - 2s/epoch - 60ms/step
# Epoch 46/100
# 30/30 - 2s - loss: 1.0487 - accuracy: 0.6101 - val_loss: 1.1160 - val_accuracy: 0.5799 - 2s/epoch - 60ms/step
# Epoch 47/100
# 30/30 - 2s - loss: 1.0284 - accuracy: 0.6159 - val_loss: 1.0974 - val_accuracy: 0.5908 - 2s/epoch - 60ms/step
# Epoch 48/100
# 30/30 - 2s - loss: 1.0176 - accuracy: 0.6210 - val_loss: 1.1121 - val_accuracy: 0.5843 - 2s/epoch - 61ms/step
# Epoch 49/100
# 30/30 - 2s - loss: 1.0289 - accuracy: 0.6141 - val_loss: 1.1144 - val_accuracy: 0.5865 - 2s/epoch - 59ms/step
# Epoch 50/100
# 30/30 - 2s - loss: 1.0119 - accuracy: 0.6197 - val_loss: 1.0964 - val_accuracy: 0.5867 - 2s/epoch - 60ms/step
# Epoch 51/100
# 30/30 - 2s - loss: 1.0103 - accuracy: 0.6222 - val_loss: 1.0989 - val_accuracy: 0.5900 - 2s/epoch - 71ms/step
# Epoch 52/100
# 30/30 - 2s - loss: 1.0135 - accuracy: 0.6213 - val_loss: 1.1031 - val_accuracy: 0.5903 - 2s/epoch - 60ms/step
# Epoch 53/100
# 30/30 - 2s - loss: 1.0102 - accuracy: 0.6202 - val_loss: 1.0906 - val_accuracy: 0.5992 - 2s/epoch - 60ms/step
# Epoch 54/100
# 30/30 - 2s - loss: 0.9967 - accuracy: 0.6294 - val_loss: 1.1149 - val_accuracy: 0.5756 - 2s/epoch - 59ms/step
# Epoch 55/100
# 30/30 - 2s - loss: 1.0289 - accuracy: 0.6148 - val_loss: 1.0953 - val_accuracy: 0.5907 - 2s/epoch - 59ms/step
# Epoch 56/100
# 30/30 - 2s - loss: 0.9931 - accuracy: 0.6285 - val_loss: 1.1123 - val_accuracy: 0.5796 - 2s/epoch - 72ms/step
# Epoch 57/100
# 30/30 - 2s - loss: 0.9989 - accuracy: 0.6277 - val_loss: 1.0891 - val_accuracy: 0.5902 - 2s/epoch - 62ms/step
# Epoch 58/100
# 30/30 - 2s - loss: 0.9845 - accuracy: 0.6318 - val_loss: 1.0870 - val_accuracy: 0.5939 - 2s/epoch - 60ms/step
# Epoch 59/100
# 30/30 - 2s - loss: 1.0023 - accuracy: 0.6219 - val_loss: 1.0937 - val_accuracy: 0.5969 - 2s/epoch - 60ms/step
# Epoch 60/100
# 30/30 - 2s - loss: 0.9903 - accuracy: 0.6298 - val_loss: 1.1060 - val_accuracy: 0.5861 - 2s/epoch - 60ms/step
# Epoch 61/100
# 30/30 - 2s - loss: 0.9798 - accuracy: 0.6342 - val_loss: 1.0842 - val_accuracy: 0.5893 - 2s/epoch - 59ms/step
# Epoch 62/100
# 30/30 - 2s - loss: 0.9941 - accuracy: 0.6257 - val_loss: 1.0987 - val_accuracy: 0.5945 - 2s/epoch - 60ms/step
# Epoch 63/100
# 30/30 - 2s - loss: 0.9772 - accuracy: 0.6351 - val_loss: 1.1323 - val_accuracy: 0.5842 - 2s/epoch - 59ms/step
# Epoch 64/100
# 30/30 - 2s - loss: 0.9921 - accuracy: 0.6272 - val_loss: 1.1451 - val_accuracy: 0.5754 - 2s/epoch - 59ms/step
# Epoch 65/100
# 30/30 - 2s - loss: 0.9870 - accuracy: 0.6323 - val_loss: 1.0950 - val_accuracy: 0.5943 - 2s/epoch - 60ms/step
# Epoch 66/100
# 30/30 - 2s - loss: 0.9708 - accuracy: 0.6372 - val_loss: 1.0730 - val_accuracy: 0.5960 - 2s/epoch - 60ms/step
# Epoch 67/100
# 30/30 - 2s - loss: 0.9657 - accuracy: 0.6390 - val_loss: 1.1220 - val_accuracy: 0.5816 - 2s/epoch - 60ms/step
# Epoch 68/100
# 30/30 - 2s - loss: 0.9725 - accuracy: 0.6377 - val_loss: 1.0762 - val_accuracy: 0.6008 - 2s/epoch - 60ms/step
# Epoch 69/100
# 30/30 - 2s - loss: 0.9640 - accuracy: 0.6398 - val_loss: 1.1144 - val_accuracy: 0.5886 - 2s/epoch - 60ms/step
# Epoch 70/100
# 30/30 - 2s - loss: 0.9599 - accuracy: 0.6422 - val_loss: 1.0986 - val_accuracy: 0.5972 - 2s/epoch - 71ms/step
# Epoch 71/100
# 30/30 - 2s - loss: 0.9498 - accuracy: 0.6467 - val_loss: 1.0679 - val_accuracy: 0.6004 - 2s/epoch - 63ms/step
# Epoch 72/100
# 30/30 - 2s - loss: 0.9468 - accuracy: 0.6503 - val_loss: 1.1201 - val_accuracy: 0.5798 - 2s/epoch - 70ms/step
# Epoch 73/100
# 30/30 - 2s - loss: 0.9518 - accuracy: 0.6450 - val_loss: 1.0727 - val_accuracy: 0.6040 - 2s/epoch - 60ms/step
# Epoch 74/100
# 30/30 - 2s - loss: 0.9391 - accuracy: 0.6526 - val_loss: 1.0753 - val_accuracy: 0.5978 - 2s/epoch - 60ms/step
# Epoch 75/100
# 30/30 - 2s - loss: 0.9528 - accuracy: 0.6467 - val_loss: 1.1199 - val_accuracy: 0.5827 - 2s/epoch - 60ms/step
# Epoch 76/100
# 30/30 - 2s - loss: 0.9536 - accuracy: 0.6444 - val_loss: 1.0921 - val_accuracy: 0.5929 - 2s/epoch - 60ms/step
# Epoch 77/100
# 30/30 - 2s - loss: 0.9503 - accuracy: 0.6458 - val_loss: 1.0947 - val_accuracy: 0.5998 - 2s/epoch - 70ms/step
# Epoch 78/100
# 30/30 - 2s - loss: 0.9309 - accuracy: 0.6550 - val_loss: 1.0888 - val_accuracy: 0.5957 - 2s/epoch - 60ms/step
# Epoch 79/100
# 30/30 - 2s - loss: 0.9213 - accuracy: 0.6590 - val_loss: 1.0924 - val_accuracy: 0.5943 - 2s/epoch - 60ms/step
# Epoch 80/100
# 30/30 - 2s - loss: 0.9245 - accuracy: 0.6576 - val_loss: 1.0809 - val_accuracy: 0.6018 - 2s/epoch - 60ms/step
# Epoch 81/100
# 30/30 - 2s - loss: 0.9239 - accuracy: 0.6570 - val_loss: 1.0765 - val_accuracy: 0.6047 - 2s/epoch - 60ms/step
# Epoch 82/100
# 30/30 - 2s - loss: 0.9305 - accuracy: 0.6557 - val_loss: 1.0698 - val_accuracy: 0.6071 - 2s/epoch - 60ms/step
# Epoch 83/100
# 30/30 - 2s - loss: 0.9166 - accuracy: 0.6607 - val_loss: 1.1021 - val_accuracy: 0.5963 - 2s/epoch - 60ms/step
# Epoch 84/100
# 30/30 - 2s - loss: 0.9196 - accuracy: 0.6571 - val_loss: 1.0928 - val_accuracy: 0.5925 - 2s/epoch - 59ms/step
# Epoch 85/100
# 30/30 - 2s - loss: 0.9224 - accuracy: 0.6565 - val_loss: 1.1001 - val_accuracy: 0.6000 - 2s/epoch - 59ms/step
# Epoch 86/100
# 30/30 - 2s - loss: 0.9124 - accuracy: 0.6615 - val_loss: 1.0789 - val_accuracy: 0.6051 - 2s/epoch - 60ms/step
# Epoch 87/100
# 30/30 - 2s - loss: 0.9090 - accuracy: 0.6665 - val_loss: 1.0800 - val_accuracy: 0.6007 - 2s/epoch - 60ms/step
# Epoch 88/100
# 30/30 - 2s - loss: 0.9114 - accuracy: 0.6618 - val_loss: 1.0998 - val_accuracy: 0.5942 - 2s/epoch - 60ms/step
# Epoch 89/100
# 30/30 - 2s - loss: 0.9298 - accuracy: 0.6549 - val_loss: 1.1274 - val_accuracy: 0.5908 - 2s/epoch - 60ms/step
# Epoch 90/100
# 30/30 - 2s - loss: 0.8951 - accuracy: 0.6694 - val_loss: 1.0985 - val_accuracy: 0.6020 - 2s/epoch - 60ms/step
# Epoch 91/100
# 30/30 - 2s - loss: 0.8975 - accuracy: 0.6653 - val_loss: 1.0957 - val_accuracy: 0.5972 - 2s/epoch - 71ms/step
# Epoch 92/100
# 30/30 - 2s - loss: 0.8979 - accuracy: 0.6653 - val_loss: 1.1045 - val_accuracy: 0.6002 - 2s/epoch - 59ms/step
# Epoch 93/100
# 30/30 - 2s - loss: 0.9028 - accuracy: 0.6653 - val_loss: 1.0991 - val_accuracy: 0.5925 - 2s/epoch - 62ms/step
# Epoch 94/100
# 30/30 - 2s - loss: 0.8843 - accuracy: 0.6737 - val_loss: 1.0858 - val_accuracy: 0.6039 - 2s/epoch - 60ms/step
# Epoch 95/100
# 30/30 - 2s - loss: 0.8710 - accuracy: 0.6785 - val_loss: 1.0960 - val_accuracy: 0.6007 - 2s/epoch - 59ms/step
# Epoch 96/100
# 30/30 - 2s - loss: 0.8751 - accuracy: 0.6765 - val_loss: 1.1127 - val_accuracy: 0.5986 - 2s/epoch - 59ms/step
# Epoch 97/100
# 30/30 - 2s - loss: 0.8928 - accuracy: 0.6670 - val_loss: 1.0929 - val_accuracy: 0.6012 - 2s/epoch - 60ms/step
# Epoch 98/100
# 30/30 - 2s - loss: 0.8640 - accuracy: 0.6808 - val_loss: 1.1036 - val_accuracy: 0.5937 - 2s/epoch - 60ms/step
# Epoch 99/100
# 30/30 - 2s - loss: 0.8622 - accuracy: 0.6826 - val_loss: 1.1022 - val_accuracy: 0.6035 - 2s/epoch - 59ms/step
# Epoch 100/100
# 30/30 - 2s - loss: 0.8624 - accuracy: 0.6818 - val_loss: 1.1007 - val_accuracy: 0.6048 - 2s/epoch - 59ms/step
# attack
# getting clean data from model
# (234, 128, 2, 128)
# (7, 128, 2, 128)
# Train model with adversarial training
# 29952/50000 [================>.............] - ETA: 1s - loss: 0.0819Evaluate on clean and adversarial data
#   896/10000 [=>............................] - ETA: 23saphl
# test acc on clean examples (%): 49.107
# test acc on FGM adversarial examples (%): 42.522
# test acc on PGD adversarial examples (%): 21.763

# %% [markdown]
# ## attack

# %%
class Attack_handler:
    def __init__(self,nb_epochs= 1,eps = 0.05, adv_train = False ,batch = 128 ):
       for i,(key,value) in enumerate(locals().items()):
          if i < 1 : continue
          setattr(self,key,value)

    
    def attack(self,a,clean_limit=100):
      FLAGS = {"nb_epochs": self.nb_epochs ,"eps": self.eps,"adv_train": self.adv_train}
      self.start_attack(a,FLAGS,self.batch,clean_limit)


    
    @staticmethod
    def start_attack(a , FLAGS = {"nb_epochs": 1,"eps": 0.05,"adv_train": False} ,batch = 128,limit =100):

        lim = int(a.X_train.shape[0]/128)
        train = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in [a.X_train,a.y_train]]
        #train = [a.X_train[:100],a.y_train[:100]]
        # Load training and test data
        
        model = a.model
        loss_object = tf.keras.losses.CategoricalCrossentropy()
        optimizer = tf.optimizers.Adam(learning_rate=0.001)

        # Metrics to track the different accuracies.
        train_loss = tf.metrics.Mean(name="train_loss")
        test_acc = a.metric
        test_acc_fgsm = a.metric
        test_acc_pgd = a.metric
        
        loss_fn = a.loss_fn


        clean = a.get_clean_data(limit)
        lim = int(clean[0].shape[0]/128)
        test = [t[:lim*batch].reshape(lim,batch,*t.shape[1:]) for t in clean]
        #test = clean
        data = EasyDict(train=train, test=test)

        print(" data train [0]",data.train[0].shape)
        print(" data train [1]",data.train[1].shape)
        print(" data test [0]",data.test[0].shape)
        print(" data test [1]",data.test[1].shape)

        @tf.function
        def train_step(x, y):
            with tf.GradientTape() as tape:
                predictions = model(x)
                loss = loss_object(y, predictions)
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))
            train_loss(loss)

        print("Train model with adversarial training")
        
        #print(model(data.train[0][0]))
        # Train model with adversarial training
        for epoch in range(FLAGS["nb_epochs"]):
            # keras like display of progress
            progress_bar_train = tf.keras.utils.Progbar(50000)
            for i in range(data.train[0].shape[0]):
                x = data.train[0][i]
                y = data.train[1][i]
                if FLAGS['adv_train']:
                    # Replace clean example with adversarial example for adversarial training
                    x = projected_gradient_descent(model, x, FLAGS['eps'], 0.01, 40, np.inf,loss_fn=loss_fn,y=y)
                train_step(x,y)
                progress_bar_train.add(x.shape[0], values=[("loss", train_loss.result())])

        print("Evaluate on clean and adversarial data")
        print("getting clean data from model")
        
        # Evaluate on clean and adversarial data
        # print(data.test[1][0,0:2])
        # print(model(data.test[0][0,0:2]))

        
        progress_bar_test = tf.keras.utils.Progbar(50000)
        for i in range(data.test[0].shape[0]):
            x = data.test[0][i,:]
            y = data.test[1][i,:]
            y_pred = model(x)
            print(y.shape,y_pred.shape)
            test_acc(y, y_pred)
            x_fgm = fast_gradient_method(model, x, FLAGS['eps'], np.inf,loss_fn=loss_fn, y=y,)
            y_pred_fgm = model(x_fgm)
            test_acc_fgsm(y, y_pred_fgm)

            x_pgd = projected_gradient_descent(model, x,FLAGS['eps'], 0.01, 40, np.inf,loss_fn=loss_fn, y=y )
            y_pred_pgd = model(x_pgd)
            test_acc_pgd(y, y_pred_pgd)

            progress_bar_test.add(x.shape[0])
        
        print(a.name)    

        print(
            "test acc on clean examples (%): {:.3f}".format(test_acc.result() * 100)
        )
        print(
            "test acc on FGM adversarial examples (%): {:.3f}".format(
                test_acc_fgsm.result() * 100
            )
        )
        print(
            "test acc on PGD adversarial examples (%): {:.3f}".format(
                test_acc_pgd.result() * 100
            )
        )

        return dict(acc = test_acc.result(),acc_FGM = test_acc_fgsm.result(),acc_pdg = test_acc_pgd.result())
