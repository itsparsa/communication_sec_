# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## start

# %% [markdown]
# just paste the locataction you allocated for the google drive file, that you have been created as shourcut link based on readme description

# %%
proj_path = "/content/gdrive/MyDrive/projects"

# %%
import os 
import sys
os.chdir('/content/gdrive/MyDrive/projects')
sys.path.append('/content/gdrive/MyDrive/Models')
from attack.cleverhans_attack import *
from autoencoder import aphl 
from deepmimo import Deep_MIMO
from mist import MIST
from pe import PE
import numpy as np

# %% [markdown]
# ## aphl

# %%
a1 = aphl("/content/gdrive/MyDrive/projects/RML2016.10a/",num_train_limit = 10000)
print("training aghl")
a1.train_gpu(epochs =10,batch_size=1024, get_data_build =True )
# Out:
# training aghl
# Epoch 1/10
# 6/6 - 5s - loss: 2.3721 - categorical_crossentropy: 2.3721 - val_loss: 2.3016 - val_categorical_crossentropy: 2.3016 - 5s/epoch - 802ms/step
# Epoch 2/10
# 6/6 - 0s - loss: 2.2353 - categorical_crossentropy: 2.2353 - val_loss: 2.1379 - val_categorical_crossentropy: 2.1379 - 456ms/epoch - 76ms/step
# Epoch 3/10
# 6/6 - 0s - loss: 2.0386 - categorical_crossentropy: 2.0386 - val_loss: 1.9367 - val_categorical_crossentropy: 1.9367 - 443ms/epoch - 74ms/step
# Epoch 4/10
# 6/6 - 0s - loss: 1.8777 - categorical_crossentropy: 1.8777 - val_loss: 1.8156 - val_categorical_crossentropy: 1.8156 - 494ms/epoch - 82ms/step
# Epoch 5/10
# 6/6 - 0s - loss: 1.7801 - categorical_crossentropy: 1.7801 - val_loss: 1.7477 - val_categorical_crossentropy: 1.7477 - 488ms/epoch - 81ms/step
# Epoch 6/10
# 6/6 - 0s - loss: 1.7015 - categorical_crossentropy: 1.7015 - val_loss: 1.6673 - val_categorical_crossentropy: 1.6673 - 497ms/epoch - 83ms/step
# Epoch 7/10
# 6/6 - 1s - loss: 1.6264 - categorical_crossentropy: 1.6264 - val_loss: 1.5721 - val_categorical_crossentropy: 1.5721 - 518ms/epoch - 86ms/step
# Epoch 8/10
# 6/6 - 0s - loss: 1.5274 - categorical_crossentropy: 1.5274 - val_loss: 1.5175 - val_categorical_crossentropy: 1.5175 - 463ms/epoch - 77ms/step
# Epoch 9/10
# 6/6 - 0s - loss: 1.4548 - categorical_crossentropy: 1.4548 - val_loss: 1.4390 - val_categorical_crossentropy: 1.4390 - 432ms/epoch - 72ms/step
# Epoch 10/10
# 6/6 - 0s - loss: 1.3768 - categorical_crossentropy: 1.3768 - val_loss: 1.3387 - val_categorical_crossentropy: 1.3387 - 411ms/epoch - 69ms/step

# %%
print("attack")
att = Attack_handler(nb_epochs= 5,
                     eps = 0.5,
                     adv_train = True ,
                     batch = 64)
d = att.attack(a1,clean_limit=256)
# Out:
# attack
#  data train [0] (46, 64, 2, 128)
#  data train [1] (46, 64, 11)
#  data test [0] (2, 64, 2, 128)
#  data test [1] (2, 64, 11)
# Train model with adversarial training
#  2944/50000 [>.............................] - ETA: 2:57 - loss: 1.7639Evaluate on clean and adversarial data
# getting clean data from model
# (64, 11) (64, 11)
#    64/50000 [..............................] - ETA: 3:33(64, 11) (64, 11)
#   128/50000 [..............................] - ETA: 3:37aphl
# test acc on clean examples categorical_crossentropy : 1.744
# test acc on FGM adversarial examples categorical_crossentropy: 1.744
# test acc on PGD adversarial examples categorical_crossentropy : 1.744

# %%
m  = aphl.CNN_Class()

# %% [markdown]
# ## PE

# %%
p1 = PE(proj_path+"/project_3/PE", train_snr = np.arange(20, -4, -2),  limit = 50000, execute=False )
print("training PE")
p1.train_gpu(epochs =100,batch_size=10240 )

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.5,
                     adv_train = False ,
                     batch = 128)

d = att.attack(p1,clean_limit=100)

# %% [markdown]
# ## DEEPMIMO

# %%
mim1 = Deep_MIMO(proj_path+    '/DeepMIMO2',
                                active_BS = 5,
                                user_row_first = 2,
                                user_row_last = 10,
                                bandwidth = 0.05,
                                subcarriers = 64 ,
                                subcarriers_sampling = 1 ,
                                subcarriers_limit = 32,
                                num_paths = 1,
                                num_set_antenna_M = 2,
                                MLP_DroupOut = 0.1)

print("training DEEPMIMO")
mim1.train_gpu(epochs =10,batch_size=1024)
# Out:
# training DEEPMIMO
#
# Basestation 1
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 6241.72it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 2360.06it/s]
# Basestation 2
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 6730.83it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 1899.20it/s]
# Basestation 3
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 8761.24it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 2405.64it/s]
# Basestation 4
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 12280.59it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 2346.34it/s]
# Basestation 5
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 17763.71it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6789.95it/s]
# Basestation 1
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 21422.78it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6298.57it/s]
# Basestation 2
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 21820.23it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 7010.34it/s]
# Basestation 3
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 27331.72it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6511.51it/s]
# Basestation 4
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 21939.99it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 6702.02it/s]
# Basestation 5
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 2010/2010 [00:00<00:00, 24651.09it/s]
# Generating channels: 100%|██████████| 1809/1809 [00:00<00:00, 7098.66it/s]
# (5, 1809, 32)
# (5, 1809, 32)
# Epoch 1/10
# 2/2 - 7s - loss: 0.3517 - mean_absolute_error: 0.5273 - val_loss: 0.2800 - val_mean_absolute_error: 0.4343 - 7s/epoch - 3s/step
# Epoch 2/10
# 2/2 - 6s - loss: 0.2776 - mean_absolute_error: 0.4299 - val_loss: 0.2488 - val_mean_absolute_error: 0.4043 - 6s/epoch - 3s/step
# Epoch 3/10
# 2/2 - 6s - loss: 0.2425 - mean_absolute_error: 0.4007 - val_loss: 0.2334 - val_mean_absolute_error: 0.3883 - 6s/epoch - 3s/step
# Epoch 4/10
# 2/2 - 6s - loss: 0.2249 - mean_absolute_error: 0.3801 - val_loss: 0.2203 - val_mean_absolute_error: 0.3620 - 6s/epoch - 3s/step
# Epoch 5/10
# 2/2 - 6s - loss: 0.2052 - mean_absolute_error: 0.3505 - val_loss: 0.2102 - val_mean_absolute_error: 0.3500 - 6s/epoch - 3s/step
# Epoch 6/10
# 2/2 - 6s - loss: 0.1911 - mean_absolute_error: 0.3347 - val_loss: 0.2064 - val_mean_absolute_error: 0.3444 - 6s/epoch - 3s/step
# Epoch 7/10
# 2/2 - 6s - loss: 0.1811 - mean_absolute_error: 0.3243 - val_loss: 0.1997 - val_mean_absolute_error: 0.3343 - 6s/epoch - 3s/step
# Epoch 8/10
# 2/2 - 6s - loss: 0.1702 - mean_absolute_error: 0.3110 - val_loss: 0.1945 - val_mean_absolute_error: 0.3271 - 6s/epoch - 3s/step
# Epoch 9/10
# 2/2 - 6s - loss: 0.1600 - mean_absolute_error: 0.3002 - val_loss: 0.1907 - val_mean_absolute_error: 0.3220 - 6s/epoch - 3s/step
# Epoch 10/10
# 2/2 - 6s - loss: 0.1526 - mean_absolute_error: 0.2923 - val_loss: 0.1892 - val_mean_absolute_error: 0.3181 - 6s/epoch - 3s/step

# %% [markdown]
# the  mean square error was 0.1526
#
# but after attack it became 15.54

# %%
print("attack")
att = Attack_handler(nb_epochs= 5,
                     eps = 0.5,
                     adv_train = False ,
                     batch = 64)

d = att.attack(mim1,clean_limit=128)
# Out:
# attack
#  data train [0] (9, 64, 5, 32, 2)
#  data train [1] (9, 64, 5, 32, 2)
#  data test [0] (1, 64, 5, 32, 2)
#  data test [1] (1, 64, 5, 32, 2)
# Train model with adversarial training
#   576/50000 [..............................] - ETA: 6:19 - loss: -0.3585Evaluate on clean and adversarial data
# getting clean data from model
# (64, 5, 32, 2) (64, 5, 32, 2)
#    64/50000 [..............................] - ETA: 2:41:42deepmimo
# test acc on clean examples mean_squared_error : 15.542
# test acc on FGM adversarial examples mean_squared_error: 15.542
# test acc on PGD adversarial examples mean_squared_error : 15.542

# %% [markdown]
# ## MIST

# %%
mis1 = MIST(k = 50, rate = 1/2 ,
                      SNR_dB_start_Eb = -1 ,
                      SNR_dB_stop_Eb = 7 ,
                      SNR_points = 9 ,
                      n_samples = 10 , 
                      train_batch = 1024,
                      test_batch = 1024,
                      g1=[1,1,1],
                      g2=[1,0,1],)

print("training MIST")
mis1.train_gpu(epochs =10,batch_size=1024 )
# Out:
# training MIST
# SNR  0/9
# epoch  0/1
# 1/1 - 3s - loss: 0.3171 - ber: 0.4977 - 3s/epoch - 3s/step
# SNR  1/9
# epoch  0/1
# 1/1 - 2s - loss: 0.3136 - ber: 0.4990 - 2s/epoch - 2s/step
# SNR  2/9
# epoch  0/1
# 1/1 - 2s - loss: 0.3072 - ber: 0.4948 - 2s/epoch - 2s/step
# SNR  3/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2996 - ber: 0.4873 - 2s/epoch - 2s/step
# SNR  4/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2952 - ber: 0.4850 - 2s/epoch - 2s/step
# SNR  5/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2893 - ber: 0.4745 - 2s/epoch - 2s/step
# SNR  6/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2831 - ber: 0.4667 - 2s/epoch - 2s/step
# SNR  7/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2752 - ber: 0.4539 - 2s/epoch - 2s/step
# SNR  8/9
# epoch  0/1
# 1/1 - 2s - loss: 0.2694 - ber: 0.4457 - 2s/epoch - 2s/step

# %%
print("attack")
att = Attack_handler(nb_epochs= 1,
                     eps = 0.05,
                     adv_train = True ,
                     batch = 128)

d = att.attack(mis1,clean_limit=100)
# Out:
# attack
#  data train [0] (72, 128, 1000, 1)
#  data train [1] (72, 128, 500)
#  data test [0] (0, 128, 1000, 1)
#  data test [1] (0, 128, 500)
# Train model with adversarial training
#  2048/50000 [>.............................] - ETA: 6:49:37 - loss: 2789.7756
